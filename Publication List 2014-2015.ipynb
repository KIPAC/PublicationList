# %%
from PublicationListUtils import *

# %%
url = 'https://docs.google.com/spreadsheets/d/1Ok5i25gibuLTHoRhGhmNMqTplMh--0-i4L_8cxzkUxI/export?format=csv&gid=147959823'
members = load_members_from_google_sheets(url)

# %%
articles = Articles(query_constraints={'pubdate':'["2015-08-00" TO "2016-06-99"]', 
                                       'database':'("astronomy" OR "physics")'})

# %%
for member in members:
    print member['key'], articles.add(member)
# Out:
# Noah Kurinsky 1
# Yajie Yuan 5
# Hongjun An 6
# Keith Thompson 7
# Jean-Baptiste Ruffio 4
# Mandeep Gill 2
# Aaron Roodman 45
# Yao-Yuan Mao 10
# Phil Marshall 12
# Christopher Williams 3
# Maria Dainotti 2
# Anders Borgland 5
# Warren Morningstar 2
# Tom Shutt 6
# Makoto Asai 7
# Fatima Rubio da Costa 4
# Ralf Kaehler 0
# Tom Abel 5
# Philipp Mertsch 2
# Elisabeth Krause 11
# Marco Viero 10
# Irina Zhuravleva 11
# Patricia Burchat 9
# Marc Williamson 3
# Jialu Zhu 0
# William East 8
# James Panetta 0
# Maria Elena Monzani 31
# Joshua Meyers 0
# Stefan Funk 18
# Dmitry Malyshev 6
# Daniel Green 1
# Eva Silverstein 4
# Ondrej Urban 3
# Elena Orlando 31
# Anja von der Linden 10
# Anna Franckowiak 18
# Eric Charles 1
# Miguel Sanchez-Conde 2
# Stewart Koppell 0
# Matthew Wood 3
# Debbie Bard 10
# Rajiv Krishnakumar 2
# Dan Akerib 7
# Ki Won Yoon 8
# Blas Cabrera 5
# Kent Irwin 23
# Qingrong Chen 0
# Tobias Jogler 22
# Greg Madejski 21
# Norbert Werner 14
# Julie Hlavacek-Larrondo 8
# Alice Allafort 1
# Saptarshi Chaudhuri 2
# Rachel Reddick 1
# Adam Snyder 0
# Elliott Bloom 20
# Yashar Hezaveh 6
# Richard Anantua 1
# Rebecca Canning 8
# Dongwoo Chung 0
# Tomasz Biesiadzinski 6
# Anne Mette Frejsel 0
# Devon Powell 2
# Krzysztof Nalewajko 7
# Ryan Keisler 8
# Risa Wechsler 42
# Luigi Tibaldo 16
# Thomas Whitis 6
# Kimmy Wu 3
# Igor Moskalenko 24
# Sowmya Kamath 0
# Nadine Kurita 0
# Rafe Schindler 13
# Anna Ogorzalek 1
# Zvonimir Vlah 9
# Rob Cameron 24
# Glenn Morris 5
# Seth Digel 17
# Heather Kelly 0
# Harry Desmond 2
# Gregory Dubois-Felsmann 9
# Yu Lu 2
# Matthew Becker 15
# Simon Foreman 5
# Walter Innes 9
# Steve Allen 12
# Carlos Cunha 40
# Roger Blandford 25
# Kirk Gilmore 0
# Charlotte Hee 0
# Sam Totorica 2
# Paul Brink 5
# Warren Focke 13
# Jamie Tolan 7
# Roger Romani 17
# Ashley King 5
# Troy Porter 23
# Chao-Lin Kuo 9
# Kate Follette 12
# William Chickering 0
# Matthew Kistler 6
# Thomas Glanzman 15
# Asimina Arvanitaki 2
# Helen Craig 0
# Andrea Albert 23
# Jae Hwan Kang 0
# Chris Davis 5
# Walter Ogburn 6
# Andrew Rasmussen 0
# Renata Kallosh 19
# Michael Busha 1
# Sarah Church 3
# John Fox 0
# Andrei Linde 10
# Kimberly Jackson Palladino 7
# Kiruthika Devaraj 1
# Junichiro Katsuta 0
# James Grayson 4
# Paul Simeon 0
# Wing To 0
# Phil Scherrer 7
# Leonardo Senatore 13
# Anirban Chatterjee 0
# Frederic Effenberger 4
# Radoslaw Wojtak 4
# Richard Dubois 3
# Gary Godfrey 22
# Ron Adler 2
# Eli Rykoff 43
# Richard Partridge 3
# Amy Furniss 7
# Kristi Schneck 3
# Matt Sieth 0
# Steve Kahn 7
# Giorgio Gratta 8
# Sam Skillman 2
# Jonathan Zrake 9
# Adam Mantz 7
# Vahe Petrosian 14
# Nicola Omodei 15
# Joe DeRose 2
# Peter Sturrock 3
# Kevin Reil 18
# Peter Graham 10
# Tony Li 1
# David Burke 34
# Zhang Zhang 0
# Matthew Lewandowski 1
# Jim Chiang 22
# Ranjan Laha 5
# Rosemary Bramante 6
# Warit Mitthumsiri 0
# Michael Baumer 1
# Patrick Ingraham 1
# Bryant Garcia 0
# Zeesh Ahmed 19
# Giacomo Vianello 23
# Leonard Susskind 4
# Joanne Bogart 0
# Bruce Macintosh 25
# Ben Lehmann 1
# Alex Sugarbaker 1
# Mark Allen 0
# Peter Lewis 0
# Bob Wagoner 1
# Eugenio Bottacini 23
# Eduardo Rozo 22
# Adam Wright 0
# Sarah Kernasovskiy 7
# Peter Michelson 25

# %%
articles.whiten_member_collab()

# %%
with open('white_list.txt') as f:
    white_list = [l.strip() for l in f]
articles.white_list(white_list)

# %%
with open('remove_list.txt') as f:
    remove_list = [l.strip() for l in f]
articles.remove(remove_list)

# %%
require_verification = articles.get_require_verification()
for item in require_verification:
    print u'{0[bibcode]} [{1}?]\n"{0[title]}" by {0[first_author]} et al.\n'.format(item, u'? '.join(item['to_verify']))
# Out:
# 2016arXiv160407821D [Aaron Roodman?]
# "Cosmic Visions Dark Energy: Technology" by Dodelson, Scott et al.
#
# 2016arXiv160600209I [Anna Franckowiak?]
# "All-flavour Search for Neutrinos from Dark Matter Annihilations in the Milky Way with IceCube/DeepCore" by IceCube collaboration et al.
#
# 2015ARNPS..6559001G [Peter Graham?]
# "Experimental Searches for the Axion and Axion-Like Particles" by Graham, Peter W. et al.
#
# 2016arXiv160206446A [Greg Madejski?]
# "NuSTAR, Swift, and GROND observations of the flaring MeV blazar: PMN J0641$-$0320" by Ajello, M. et al.
#
# 2015arXiv150805026N [Greg Madejski? Amy Furniss?]
# "First study of Mrk 501 through the eyes of NuSTAR, VERITAS and the LIDAR-corrected eyesight of MAGIC" by Noda, Koji et al.
#
# 2015PNAS..11212264F [Stefan Funk?]
# "Indirect detection of dark matter with γ rays" by Funk, Stefan et al.
#
# 2016arXiv160506569T [Kent Irwin?]
# "The Atacama Cosmology Telescope: The polarization-sensitive ACTPol instrument" by Thornton, R. J. et al.
#
# 2016arXiv160207601N [Dmitry Malyshev?]
# "Hard X-ray view of microlensing events in RX J1131-1231" by Neronov, A. et al.
#
# 2016arXiv160108216M [Dmitry Malyshev?]
# "Very high energy Fermi/LAT detection of HESS J0632+057" by Malyshev, D. et al.
#
# 2016arXiv160508371F [Makoto Asai?]
# "Multi-threaded Geant4 on the Xeon-Phi with Complex High-Energy Physics Geometry" by Farrell, Steven et al.
#
# 2016arXiv160404670D [Risa Wechsler? Harry Desmond?]
# "The Faber-Jackson relation and Fundamental Plane from halo abundance matching" by Desmond, Harry et al.
#
# 2016arXiv160304951R [Fatima Rubio da Costa? Vahe Petrosian?]
# "Data-driven Radiative Hydrodynamic Modeling of the 2014 March 29 X1.0 Solar Flare" by Rubio da Costa, Fatima et al.
#
# 2016arXiv160604106H [Yao-Yuan Mao?]
# "High-Precision Forward Modeling of Large-Scale Structure: An open-source approach with Halotools" by Hearin, Andrew et al.
#
# 2015arXiv150805388T [Yao-Yuan Mao?]
# "Sussing Merger Trees: A proposed Merger Tree data format" by Thomas, Peter A. et al.
#
# 2015arXiv151101530K [Matthew Kistler?]
# "Problems and Prospects from a Flood of Extragalactic TeV Neutrinos in IceCube" by Kistler, Matthew D. et al.
#
# 2015arXiv151200546C [Renata Kallosh? Andrei Linde?]
# "Inflatino-less Cosmology" by Carrasco, John Joseph M. et al.
#
# 2016arXiv160608068R [Phil Scherrer?]
# "Statistical analysis of acoustic wave parameters near active regions" by Rabello Soares, M. Cristina et al.
#
# 2015arXiv151201203L [Andrei Linde?]
# "A brief history of the multiverse" by Linde, Andrei et al.
#
# 2016arXiv160406138G [Carlos Cunha?]
# "Host Galaxy Identification for Supernova Surveys" by Gupta, Ravi R. et al.
#
# 2016arXiv160601860G [Peter Graham?]
# "A Resonant Mode for Gravitational Wave Detectors based on Atom Interferometry" by Graham, Peter W. et al.
#
# 2015arXiv150902480V [Matthew Wood?]
# "Prospects for Measuring the Positron Excess with the Cherenkov Telescope Array" by Vandenbroucke, Justin et al.
#
# 2015arXiv150901480D [Luigi Tibaldo? Stefan Funk?]
# "The first GCT camera for the Cherenkov Telescope Array" by De Franco, A. et al.
#
# 2016arXiv160505373A [Roger Romani?]
# "Binary Black Holes, Gas Sloshing, and Cold Fronts in the X-ray Halo Hosting 4C+37.11" by Andrade-Santos, Felipe et al.
#
# 2016arXiv160404908R [Giorgio Gratta?]
# "Search for Screened Interactions Below the Dark Energy Length Scale Using Optically Levitated Microspheres" by Rider, Alexander D. et al.
#
# 2015arXiv151000702T [Maria Elena Monzani?]
# "Results from the first use of low radioactivity argon in a dark matter search" by The DarkSide Collaboration et al.
#
# 2016arXiv160604757A [Zeesh Ahmed?]
# "Dirichlet spectrum of the paradigm model of complex PT-symmetric potential: $V(x)=-(ix)^N$" by Ahmed, Zafar et al.
#
# 2016arXiv160503541S [Adam Mantz?]
# "A Comparison and Joint Analysis of Sunyaev-Zel'dovich Effect Measurements from Planck and Bolocam for a set of 47 Massive Galaxy Clusters" by Sayers, Jack et al.
#
# 2016arXiv160403958A [Asimina Arvanitaki?]
# "Black Hole Mergers and the QCD Axion at Advanced LIGO" by Arvanitaki, Asimina et al.
#
# 2015ARNPS..65..245F [Stefan Funk?]
# "Ground- and Space-Based Gamma-Ray Astronomy" by Funk, Stefan et al.
#
# 2016arXiv160605404A [Tobias Jogler? Stefan Funk?]
# "Extended VHE gamma-ray emission towards SGR1806-20, LBV1806-20, and stellar cluster Cl*1806-20" by Abdalla, H. et al.
#
# 2015arXiv150902189W [Luigi Tibaldo?]
# "Creating a high-resolution picture of Cygnus with the Cherenkov Telescope Array" by Weinstein, Amanda et al.
#
# 2016arXiv160104761F [Marc Williamson?]
# "HST hot-Jupiter transmission spectral survey: Clear skies for cool Saturn WASP-39b" by Fischer, Patrick D. et al.
#
# 2016arXiv160106140C [Ranjan Laha?]
# "Constraints on dark matter annihilation to fermions and a photon" by Chowdhury, Debtosh et al.
#
# 2016arXiv160502137S [Ashley King?]
# "A NuSTAR observation of the reflection spectrum of the low mass X-ray binary 4U 1728-34" by Sleator, Clio C. et al.
#
# 2015arXiv151001639T [Amy Furniss?]
# "VERITAS Collaboration Contributions to the 34th International Cosmic Ray Conference" by The VERITAS Collaboration et al.
#
# 2015arXiv150904289H [Risa Wechsler?]
# "Rhapsody-G simulations I: the cool cores, hot gas and stellar content of massive galaxy clusters" by Hahn, Oliver et al.
#
# 2015arXiv150806128C [Miguel Sanchez-Conde?]
# "Prospects for Indirect Dark Matter Searches with the Cherenkov Telescope Array (CTA)" by Carr, J. et al.
#
# 2015arXiv151207914J [Gregory Dubois-Felsmann?]
# "The LSST Data Management System" by Jurić, Mario et al.
#
# 2015arXiv151008849S [Greg Madejski?]
# "Extremes of the jet-accretion power relation of blazars, as explored by NuSTAR" by Sbarrato, T. et al.
#
# 2016arXiv160307743C [Zeesh Ahmed?]
# "Optofluidic Temperature and Pressure Measurements with Fiber Bragg Gratings Embedded in Microfluidic Devices" by Cooksey, Gregory A. et al.
#
# 2016arXiv160408157K [Bruce Macintosh?]
# "Astrometric Monitoring of the HR 8799 Planets: Orbit Constraints from Self-Consistent Measurements" by Konopacky, Q. M. et al.
#
# 2016arXiv160400048B [Risa Wechsler? Eduardo Rozo?]
# "Constraining the Mass-Richness Relationship of redMaPPer Clusters with Angular Clustering" by Baxter, Eric J. et al.
#
# 2016arXiv160304405S [Zvonimir Vlah?]
# "Fast Large Scale Structure Perturbation Theory using 1D FFTs" by Schmittfull, Marcel et al.
#
# 2016arXiv160309303H [Anders Borgland? Debbie Bard?]
# "ASCR/HEP Exascale Requirements Review Report" by Habib, Salman et al.
#
# 2016arXiv160605377D [Marco Viero?]
# "HELP: star formation as function of galaxy environmentwith Herschel" by Duivenvoorden, S. et al.
#
# 2015arXiv151104132C [Christopher Williams?]
# "ALFABURST: A realtime fast radio burst monitor for the Arecibo telescope" by Chennamangalam, Jayanth et al.
#
# 2015arXiv150806075H [Tobias Jogler?]
# "Second large-scale Monte Carlo study for the Cherenkov Telescope Array" by Hassan, T. et al.
#
# 2016arXiv160501065H [Eduardo Rozo? Eli Rykoff?]
# "Intrinsic alignments in redMaPPer clusters -- I. Central galaxy alignments and angular segregation of satellites" by Huang, Hung-Jin et al.
#
# 2016arXiv160501792D [Makoto Asai?]
# "Extending Geant4 Parallelism with External Libraries (MPI, TBB) and Its Use on HPC Resources" by Dotti, Andrea et al.
#
# 2015arXiv150801419K [Zeesh Ahmed?]
# "Fabrication and Characterization of On-Chip Integrated Silicon Photonic Bragg Grating and Photonic Crystal Cavity Thermometers" by Klimov, Nikolai N. et al.
#
# 2016arXiv160609245K [Renata Kallosh?]
# "String Theory Origin of Constrained Multiplets" by Kallosh, Renata et al.
#
# 2016arXiv160107266E [Giorgio Gratta?]
# "First Search for Lorentz and CPT Violation in Double Beta Decay with EXO-200" by EXO-200 Collaboration et al.
#
# 2015arXiv151006226A [Zeesh Ahmed?]
# "Real discrete spectrum of complex PT-symmetric scattering potentials" by Ahmed, Zafar et al.
#
# 2015arXiv151006442S [Kent Irwin?]
# "Evidence for the kinematic Sunyaev-Ze\v{l}dovich effect with ACTPol and velocity reconstruction from BOSS" by Schaan, Emmanuel et al.
#
# 2016arXiv160105797O [Matthew Kistler?]
# "Young and Millisecond Pulsar GeV Gamma-ray Fluxes from the Galactic Center and Beyond" by O'Leary, Ryan M. et al.
#
# 2016arXiv160606927L [Yu Lu?]
# "Coupled-Channel Effects for the Bottomonium with Realistic Wave Functions" by Lu, Yu et al.
#
# 2015arXiv150801433J [Zeesh Ahmed?]
# "Developing Microwave Photonic Temperature Sensors" by Jamgochian, Arec et al.
#
# 2015arXiv150902434P [Stefan Funk?]
# "FlashCam: a fully-digital camera for the medium-sized telescopes of the Cherenkov Telescope Array" by Pühlhofer, G. et al.
#
# 2016arXiv160402106S [Christopher Williams?]
# "Observing the carbon-climate system" by Schimel, David et al.
#
# 2016arXiv160507315A [Zeesh Ahmed?]
# "The paradoxical zero reflection at zero energy" by Ahmed, Zafar et al.
#
# 2016arXiv160505333T [Phil Marshall?]
# "Time Delay Cosmography" by Treu, Tommaso et al.
#
# 2015arXiv151005996S [Peter Sturrock?]
# "Concerning the variability of beta-decay measurements" by Sturrock, P. A. et al.
#
# 2016arXiv160603316A [Maria Elena Monzani?]
# "The Electronics and Data Acquisition System for the DarkSide-50 Veto Detectors" by Agnes, P. et al.
#
# 2016arXiv160603518R [Roger Romani?]
# "Intra-Binary Shock Heating of Black Widow Companions" by Romani, Roger W. et al.
#
# 2016arXiv160603640S [Eva Silverstein?]
# "TASI lectures on cosmological observables and string theory" by Silverstein, Eva et al.
#
# 2016arXiv160102665A [Marco Viero?]
# "HerMES: A search for high-redshift dusty galaxies in the HerMES Large Mode Survey - Catalogue, number counts and early results" by Asboth, V. et al.
#
# 2016arXiv160400444K [Renata Kallosh? Andrei Linde?]
# "Cosmological Attractors and Asymptotic Freedom of the Inflaton Field" by Kallosh, Renata et al.
#
# 2016arXiv160607818H [Julie Hlavacek-Larrondo?]
# "Chandra observations of the hyper-luminous infrared galaxy IRAS F15307+3252" by Hlavacek-Larrondo, J. et al.
#
# 2016arXiv160305981Z [Julie Hlavacek-Larrondo?]
# "Galaxy Populations in the 26 most massive Galaxy Clusters in the South Pole Telescope SZE Survey" by Zenteno, A. et al.
#
# 2015arXiv150806042M [Tobias Jogler?]
# "Monte Carlo Performance Studies of Candidate Sites for the Cherenkov Telescope Array" by Maier, G. et al.
#
# 2016arXiv160508999C [Irina Zhuravleva?]
# "Arithmetic with X-ray images of galaxy clusters: effective equation of state for small-scale perturbations in the ICM" by Churazov, E. et al.
#
# 2015arXiv151108770S [Peter Sturrock?]
# "Comparative Analysis of Brookhaven National Laboratory Nuclear Decay Data and Super-Kamiokande Neutrino Data: Indication of a Solar Connection" by Sturrock, P. A. et al.
#
# 2015arXiv151105199K [Matthew Kistler?]
# "On TeV Gamma Rays and the Search for Galactic Neutrinos" by Kistler, Matthew D. et al.
#
# 2016arXiv160408611F [Eduardo Rozo? Eli Rykoff?]
# "Tidal stripping as a test of satellite quenching in redMaPPer clusters" by Fang, Yuedong et al.
#
# 2016arXiv160603633C [Simon Foreman? Leonardo Senatore?]
# "Efficient exploration of cosmology dependence in the EFT of LSS" by Cataneo, Matteo et al.
#
# 2016arXiv160401069K [Ashley King?]
# "Studying the nucleus of comet 9P/Tempel 1 using the structure of the Deep Impact ejecta cloud at the early stages of its development" by Kolokolova, Ludmilla et al.
#
# 2016arXiv160201678B [Renata Kallosh?]
# "Construction of the de Sitter supergravity" by Bergshoeff, Eric et al.
#
# 2015SPIE.9614E....V [Chris Davis?]
# "Laser Communication and Propagation through the Atmosphere and Oceans" by van Eijk, s. ):Alexander M. J. et al.
#
# 2016arXiv160106286B [Marc Williamson?]
# "Trends in sea-ice variability on the way to an ice-free Arctic" by Bathiany, Sebastian et al.
#
# 2015arXiv150800661A [Zeesh Ahmed?]
# "Avoided crossings of energy levels in one-dimension" by Ahmed, Zafar et al.
#
# 2016arXiv160606775B [Eduardo Rozo? Carlos Cunha?]
# "The Evolution of Active Galactic Nuclei in Clusters of Galaxies from the Dark Energy Survey" by Bufanda, E. et al.
#
# 2016arXiv160500966C [Ryan Keisler?]
# "Maps of the Magellanic Clouds from Combined South Pole Telescope and Planck Data" by Crawford, T. M. et al.
#
# 2015arXiv150908115Y [Hongjun An?]
# "NuSTAR Observations of Magnetar 1E 1048.1$-$5937" by Yang, C. et al.
#
# 2016arXiv160305218G [Kevin Reil?]
# "Characteristics of Four Upward-pointing Cosmic-ray-like Events Observed with ANITA" by Gorham, P. W. et al.
#
# 2015arXiv150907876B [Leonard Susskind?]
# "Complexity Equals Action" by Brown, Adam R. et al.
#
# 2016arXiv160607930G [Zeesh Ahmed?]
# "Photon asymmetry measurements of $\overrightarrow{\gamma} \mathrm{p} \rightarrow \pi^{0} \mathrm{p}$ for E$_{\gamma}$=320$-$650 MeV" by Gardner, S. et al.
#
# 2015arXiv151100723K [Matthew Kistler?]
# "Gamma Rays, Electrons, Hard X-Rays, and the Central Parsec of the Milky Way" by Kistler, Matthew D. et al.
#
# 2016arXiv160509417L [Zvonimir Vlah?]
# "Massive neutrinos in nonlinear large scale structure: A consistent perturbation theory" by Levi, Michele et al.
#
# 2016arXiv160203036A [Andrea Albert?]
# "Constraints on the neutrino emission from the Galactic Ridge with the ANTARES telescope" by Adrián-Martínez, S. et al.
#
# 2016arXiv160503088S [Peter Sturrock?]
# "Comparative analyses of 90Sr/90Y90 decay measurements at the Physikalisch-Technische Bundesanstalt and 222Rn decay measurements at the Geological Survey of Israel. Evidence of a solar influence" by Sturrock, Peter et al.
#
# 2016arXiv160506161E [Bruce Macintosh?]
# "Bringing "The Moth" to Light: A Planet-Sculpting Scenario for the HD 61005 Debris Disk" by Esposito, Thomas M. et al.
#
# 2015arXiv151001269S [Amy Furniss?]
# "Science Highlights from VERITAS" by Staszak, D. et al.
#
# 2016arXiv160504022P [Vahe Petrosian?]
# "Particle Acceleration in Solar Flares and Associated CME Shocks" by Petrosian, Vahe' et al.
#
# 2015arXiv151109451M [Philipp Mertsch?]
# "Small-scale anisotropies of cosmic rays from relative diffusion" by Mertsch, Philipp et al.
#
# 2015arXiv150907834R [Roger Romani?]
# "A binary counterpart for 2FGL J2039.6-5620" by Romani, Roger W. et al.
#
# 2016arXiv160105779K [Elisabeth Krause?]
# "CosmoLike - Cosmological Likelihood Analyses for Photometric Galaxy Surveys" by Krause, Elisabeth et al.
#
# 2015arXiv151208378A [Hongjun An?]
# "Broad Diphotons from Narrow States" by An, Haipeng et al.
#
# 2015arXiv150805190F [Stefan Funk?]
# "Space- and Ground-Based Gamma-Ray Astrophysics" by Funk, S. et al.
#
# 2016arXiv160602305A [Hongjun An?]
# "Strong CMB Constraint On P-Wave Annihilating Dark Matter" by An, Haipeng et al.
#
# 2015arXiv151101465B [Leonardo Senatore?]
# "Linear response to long wavelength fluctuations using curvature simulations" by Baldauf, Tobias et al.
#
# 2016arXiv160600513F [Leonardo Senatore? Eva Silverstein?]
# "Productive Interactions: heavy particles and non-Gaussianity" by Flauger, Raphael et al.
#
# 2016arXiv160506552E [Giorgio Gratta?]
# "An Optimal Energy Estimator to Reduce Correlated Noise for the EXO-200 Light Readout" by EXO-200 Collaboration et al.
#
# 2015arXiv150900780B [Zeesh Ahmed?]
# "Electroexcitation of the $\Delta^{+}(1232)$ at low momentum transfer" by Blomberg, A. et al.
#
# 2016arXiv160604541A [Peter Graham? Asimina Arvanitaki?]
# "Search for light scalar dark matter with atomic gravitational wave detectors" by Arvanitaki, Asimina et al.
#
# 2016arXiv160405723S [Yashar Hezaveh?]
# "ALMA Imaging and Gravitational Lens Models of South Pole Telescope-Selected Dusty, Star-Forming Galaxies at High Redshifts" by Spilker, Justin et al.
#
# 2016arXiv160204389R [Christopher Williams?]
# "Commissioning of ALFABURST: initial tests and results" by Rajwade, Kaustubh et al.
#
# 2015arXiv151008545H [Anders Borgland? Makoto Asai?]
# "High Energy Physics Forum for Computational Excellence: Working Group Reports (I. Applications Software II. Software Libraries and Tools III. Systems)" by Habib, Salman et al.
#
# 2015arXiv151102280B [Eugenio Bottacini?]
# "Fermi-LAT Observations of 2014 May-July outburst from 3C 454.3" by Britto, Richard J. G. et al.
#
# 2016arXiv160203520K [Leonardo Senatore?]
# "Inhomogeneous Anisotropic Cosmology" by Kleban, Matthew et al.
#
# 2016arXiv160502036C [Carlos Cunha?]
# "Testing the lognormality of the galaxy and weak lensing convergence distributions from Dark Energy Survey maps" by Clerkin, L. et al.
#
# 2015arXiv151004530A [Hongjun An?]
# "Direct detection prospects of dark vectors with xenon-based dark matter experiments" by An, Haipeng et al.
#
# 2016arXiv160303035M [Julie Hlavacek-Larrondo?]
# "The Evolution of the Intracluster Medium Metallicity in Sunyaev-Zel'dovich-Selected Galaxy Clusters at 0 〈 z 〈 1.5" by McDonald, M. et al.
#
# 2016arXiv160403507W [Kent Irwin? Ryan Keisler?]
# "Millimeter Transient Point Sources in the SPTpol 100 Square Degree Survey" by Whitehorn, N. et al.
#
# 2016arXiv160207653A [Kent Irwin?]
# "Quantum walk on spin network" by Amaral, M. M. et al.
#
# 2016arXiv160307726A [Zeesh Ahmed?]
# "Revisiting double Dirac delta potential" by Ahmed, Zafar et al.
#
# 2016arXiv160508781K [Ranjan Laha? Matthew Kistler?]
# "Multi-PeV Signals from a New Astrophysical Neutrino Flux Beyond the Glashow Resonance" by Kistler, Matthew D. et al.
#
# 2016arXiv160205411A [Andrea Albert?]
# "High-energy Neutrino follow-up search of Gravitational Wave Event GW150914 with ANTARES and IceCube" by Adrián-Martínez, S. et al.
#
# 2015arXiv150801156L [Zeesh Ahmed?]
# "Fiber Bragg Gratings Embedded in 3D-Printed Scaffolds" by Liacouras, Peter et al.
#
# 2015arXiv151202089S [Eva Silverstein?]
# "Inflation in string theory confronts data/Les mod\`eles d'inflation en th\'eorie des cordes face aux observations" by Silverstein, Eva et al.
#
# 2015arXiv151206831L [Leonardo Senatore? Matthew Lewandowski?]
# "On the EFT of Large Scale Structures in Redshift Space" by Lewandowski, Matthew et al.
#
# 2016arXiv160107683H [Rajiv Krishnakumar?]
# "Quantum state magnification" by Hosten, O. et al.
#
# 2015arXiv150805827R [Matthew Wood?]
# "Limits to dark matter properties from a combined analysis of MAGIC and Fermi-LAT observations of dwarf satellite galaxies" by Rico, Javier et al.
#
# 2016arXiv160601165M [Norbert Werner?]
# "On the origin of central abundances in the hot intra-cluster medium - I. Individual and average abundance ratios from XMM-Newton EPIC" by Mernier, François et al.
#
# 2016arXiv160404612F [Zvonimir Vlah?]
# "Non-linear Fields in Generalized Cosmologies" by Fasiello, Matteo et al.
#
# 2016arXiv160107459A [Andrea Albert?]
# "Letter of Intent for KM3NeT2.0" by Adrián-Martínez, S. et al.
#
# 2016arXiv160106063M [Eduardo Rozo? Eli Rykoff?]
# "Detection of the Splashback Radius and Halo Assembly bias of Massive Galaxy Clusters" by More, Surhud et al.
#
# 2015arXiv151101159K [Matthew Kistler?]
# "A Tale of Two Pulsars and the Origin of TeV Gamma Rays from the Galactic Center" by Kistler, Matthew D. et al.
#
# 2015arXiv150807479Y [Giacomo Vianello?]
# "A high-level analysis framework for HAWC" by Younk, Patrick W. et al.
#
# 2016arXiv160407626D [Aaron Roodman?]
# "Cosmic Visions Dark Energy: Science" by Dodelson, Scott et al.
#
# 2016arXiv160307688A [Zeesh Ahmed?]
# "Fiber Bragg Grating Based Thermometry" by Ahmed, Zeeshan et al.
#
# 2016arXiv160307690A [Zeesh Ahmed?]
# "Towards Photonics Enabled Quantum Metrology of Temperature, Pressure and Vacuum" by Ahmed, Zeeshan et al.
#
# 2016arXiv160302661K [Renata Kallosh?]
# "Orthogonal Nilpotent Superfields from Linear Models" by Kallosh, Renata et al.
#
# 2015arXiv151204100D [Leonardo Senatore?]
# "Boost Breaking in the EFT of Inflation" by Delacretaz, Luca V. et al.
#
# 2016arXiv160303670G [Krzysztof Nalewajko?]
# "Covering factors of the dusty obscurers in radio-loud and radio-quiet quasars" by Gupta, Maitrayee et al.
#
# 2015arXiv151102149A [Andrea Albert?]
# "First combined search for neutrino point-sources in the Southern Hemisphere with the ANTARES and IceCube neutrino telescopes" by ANTARES Collaboration et al.
#
# 2015ARNPS..65..485G [Peter Graham?]
# "Experimental Searches for the Axion and Axion-Like Particles" by Graham, Peter W. et al.
#
# 2016arXiv160607039D [Elisabeth Krause? Marco Viero?]
# "Science Impacts of the SPHEREx All-Sky Optical to Near-Infrared Spectral Survey: Report of a Community Workshop Examining Extragalactic, Galactic, Stellar and Planetary Science" by Doré, Olivier et al.
#
# 2016arXiv160402589S [Leonard Susskind?]
# "Copenhagen vs Everett, Teleportation, and ER=EPR" by Susskind, Leonard et al.
#
# 2016arXiv160408614B [Daniel Green?]
# "A New Target for Cosmic Axion Searches" by Baumann, Daniel et al.

# %%
print 'total #', articles.get_count()
print 'arxiv #', articles.get_count(arxiv_only=True)
print 'awaits verification', len(require_verification)
# Out:
# total # 498
# arxiv # 177
# awaits verification 139

# %%
with open('tex/entries.tex', 'w') as f:
    for l in articles.generate_formatted_output(AuthorsFormatter(name_formatter_tex), entry_formatter_tex):
        f.write(l + '\n')

# %%
output = articles.generate_formatted_output(AuthorsFormatter(name_formatter_html), entry_formatter_html)

with open('html/template.html', 'r') as f:
    with open('html/index.html', 'w') as fo:
        for l in f:
            if l.strip() == '<!-- INSERT HERE -->':
                for o in output:
                    fo.write(o+'\n')
            else:
                fo.write(l)
